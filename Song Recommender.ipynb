# %%
triplets_file = 'kaggle_visible_evaluation_triplets.txt'
songs_metadata_file = 'song_data.csv'

# %%
import pandas

# %%
song_df_1 = pandas.read_table(triplets_file,header=None)
song_df_1.columns = ['user_id', 'song_id', 'listen_count']

# %%
song_df_2 =  pandas.read_csv(songs_metadata_file)

song_df = pandas.merge(song_df_1, song_df_2.drop_duplicates(['song_id']), on="song_id", how="left")

# %%
song_df.head()
# Out:
#                                     user_id             song_id  listen_count  \
# 0  fd50c4007b68a3737fe052d5a4f78ce8aa117f3d  SOBONKR12A58A7A7E0             1
# 1  fd50c4007b68a3737fe052d5a4f78ce8aa117f3d  SOEGIYH12A6D4FC0E3             1
# 2  fd50c4007b68a3737fe052d5a4f78ce8aa117f3d  SOFLJQZ12A6D4FADA6             1
# 3  fd50c4007b68a3737fe052d5a4f78ce8aa117f3d  SOHTKMO12AB01843B0             1
# 4  fd50c4007b68a3737fe052d5a4f78ce8aa117f3d  SODQZCY12A6D4F9D11             1
#
#                                                title  \
# 0                                     You're The One
# 1  Horn Concerto No. 4 in E flat K495: II. Romanc...
# 2                                           Tive Sim
# 3  Catch You Baby (Steve Pitron & Max Sanna Radio...
# 4                                        El Cuatrero
#
#                            release  \
# 0               If There Was A Way
# 1  Mozart - Eine kleine Nachtmusik
# 2                 Nova Bis-Cartola
# 3                   Catch You Baby
# 4      From Argentina To The World
#
#                                          artist_name  year
# 0                                      Dwight Yoakam  1990
# 1  Barry Tuckwell/Academy of St Martin-in-the-Fie...     0
# 2                                            Cartola  1974
# 3                                      Lonnie Gordon     0
# 4                                        Miguel Calo  2001

# %%
song_df['song'] = song_df['title'] + " - " + song_df['artist_name']
song_grouped = song_df.groupby(['song']).agg({'listen_count': 'count'}).reset_index()
grouped_sum = song_grouped['listen_count'].sum()
song_grouped['percentage']  = song_grouped['listen_count'].div(grouped_sum)*100
song_grouped.sort_values(['listen_count', 'song'], ascending = [0,1])
# Out:
#                                                      song  listen_count  \
# 116491                           Sehr kosmisch - Harmonia          5043
# 147834                                       Undo - Björk          4483
# 160389                     You're The One - Dwight Yoakam          4136
# 33504   Dog Days Are Over (Radio Edit) - Florence + Th...          3780
# 110728                            Revelry - Kings Of Leon          3672
# 116240                              Secrets - OneRepublic          3430
# 57994   Horn Concerto No. 4 in E flat K495: II. Romanc...          3272
# 56238                            Hey_ Soul Sister - Train          2791
# 44083                      Fireflies - Charttraxx Karaoke          2725
# 143094                                 Tive Sim - Cartola          2668
# 96988                     OMG - Usher featuring will.i.am          2260
# 35966                 Drop The World - Lil Wayne / Eminem          2226
# 21719   Catch You Baby (Steve Pitron & Max Sanna Radio...          2097
# 84701                                    Marry Me - Train          1990
# 148565                       Use Somebody - Kings Of Leon          1911
# 120207            Sincerité Et Jalousie - Alliance Ethnik          1797
# 110337                       Représente - Alliance Ethnik          1769
# 18736     0.098213
# 71135     0.097799
# 60791     0.093526
# ...            ...
# 161978    0.000069
# 161980    0.000069
# 161981    0.000069
# 161983    0.000069
# 161988    0.000069
# 161989    0.000069
# 161990    0.000069
# 161993    0.000069
# 161995    0.000069
# 161997    0.000069
# 161999    0.000069
# 162000    0.000069
# 162001    0.000069
# 162002    0.000069
# 162005    0.000069
# 162007    0.000069
# 162008    0.000069
# 162009    0.000069
# 162013    0.000069
# 162018    0.000069
# 162019    0.000069
# 162020    0.000069
# 162028    0.000069
# 162030    0.000069
# 162032    0.000069
# 162033    0.000069
# 162035    0.000069
# 162037    0.000069
# 162039    0.000069
# 162046    0.000069
#
# [162047 rows x 3 columns]

# %%
users = song_df['user_id'].unique()
len(users) ## return 365 unique users
# Out:
# 110000

# %%
songs = song_df['song'].unique()
len(songs) ## return 5151 unique songs
# Out:
# 162048

# %%
from sklearn.model_selection import train_test_split

# %%
train_data, test_data = train_test_split(song_df, test_size = 0.20, random_state=0)

# %%
import Recommenders

# %%
pm = Recommenders.popularity_recommender_py()
pm.create(train_data, 'user_id', 'song')
#user the popularity model to make some prediction
user_id = users[5]
pm.recommend(user_id)
# Out:
#                                          user_id  \
# 106308  91b8fac7dc5e03f6cfaf6e2aa7171f14a8354d62
# 135094  91b8fac7dc5e03f6cfaf6e2aa7171f14a8354d62
# 146615  91b8fac7dc5e03f6cfaf6e2aa7171f14a8354d62
# 30557   91b8fac7dc5e03f6cfaf6e2aa7171f14a8354d62
# 101018  91b8fac7dc5e03f6cfaf6e2aa7171f14a8354d62
# 106074  91b8fac7dc5e03f6cfaf6e2aa7171f14a8354d62
# 52948   91b8fac7dc5e03f6cfaf6e2aa7171f14a8354d62
# 51320   91b8fac7dc5e03f6cfaf6e2aa7171f14a8354d62
# 40210   91b8fac7dc5e03f6cfaf6e2aa7171f14a8354d62
# 130767  91b8fac7dc5e03f6cfaf6e2aa7171f14a8354d62
#
#                                                      song  score  Rank
# 106308                           Sehr kosmisch - Harmonia   4026   1.0
# 135094                                       Undo - Björk   3597   2.0
# 146615                     You're The One - Dwight Yoakam   3311   3.0
# 30557   Dog Days Are Over (Radio Edit) - Florence + Th...   3038   4.0
# 101018                            Revelry - Kings Of Leon   2946   5.0
# 106074                              Secrets - OneRepublic   2740   6.0
# 52948   Horn Concerto No. 4 in E flat K495: II. Romanc...   2587   7.0
# 51320                            Hey_ Soul Sister - Train   2236   8.0
# 40210                      Fireflies - Charttraxx Karaoke   2201   9.0
# 130767                                 Tive Sim - Cartola   2144  10.0

# %%
is_model = Recommenders.item_similarity_recommender_py()
is_model.create(train_data, 'user_id', 'song')

# %%
user_id = users[5]
user_items = is_model.get_user_items(user_id)
#
print("------------------------------------------------------------------------------------")
print("Training data songs for the user userid: %s:" % user_id)
print("------------------------------------------------------------------------------------")

for user_item in user_items:
    print(user_item)

print("----------------------------------------------------------------------")
print("Recommendation process going on:")
print("----------------------------------------------------------------------")

#Recommend songs for the user using personalized model
is_model.recommend(user_id)
# Out:
# ------------------------------------------------------------------------------------
# Training data songs for the user userid: 91b8fac7dc5e03f6cfaf6e2aa7171f14a8354d62:
# ------------------------------------------------------------------------------------
# Passacaglia - Secret Garden
# Pastorale - Secret Garden
# In The Waiting Line - Zero 7
# Until The Morning - Thievery Corporation
# Love Letters - Dario Marianelli
# Big Yellow Taxi - Counting Crows / Vanessa Carlton
# Un Simple Histoire - Thievery Corporation
# ----------------------------------------------------------------------
# Recommendation process going on:
# ----------------------------------------------------------------------
# No. of unique songs for the user: 7
# no. of unique songs in the training set: 148122
# Non zero values in cooccurence_matrix :4630
#                                     user_id  \
# 0  91b8fac7dc5e03f6cfaf6e2aa7171f14a8354d62
# 1  91b8fac7dc5e03f6cfaf6e2aa7171f14a8354d62
# 2  91b8fac7dc5e03f6cfaf6e2aa7171f14a8354d62
# 3  91b8fac7dc5e03f6cfaf6e2aa7171f14a8354d62
# 4  91b8fac7dc5e03f6cfaf6e2aa7171f14a8354d62
# 5  91b8fac7dc5e03f6cfaf6e2aa7171f14a8354d62
# 6  91b8fac7dc5e03f6cfaf6e2aa7171f14a8354d62
# 7  91b8fac7dc5e03f6cfaf6e2aa7171f14a8354d62
# 8  91b8fac7dc5e03f6cfaf6e2aa7171f14a8354d62
# 9  91b8fac7dc5e03f6cfaf6e2aa7171f14a8354d62
#
#                                                 song     score rank
# 0                       Illumination - Secret Garden  0.045788    1
# 1                 Serenade To Spring - Secret Garden  0.030612    2
# 2  Exilio (Rewound by Thievery Corporation) - Thi...  0.028372    3
# 3                           Chaconne - Secret Garden  0.027451    4
# 4                Cee_ You and Tea - Dario Marianelli  0.025974    5
# 5                        ¡Que llueva! - Juana Molina  0.025974    6
# 6        The Cottage On The Beach - Dario Marianelli  0.025510    7
# 7                               Home - Secret Garden  0.022894    8
# 8                      Denouement - Dario Marianelli  0.022857    9
# 9  Sundial Dreams (from In the Enchanted Garden) ...  0.021978   10

# %%
is_model.get_similar_items(['U Smile - Justin Bieber'])
# Out:
# no. of unique songs in the training set: 148122
# Non zero values in cooccurence_matrix :3470
#   user_id                                            song     score rank
# 0                        Somebody To Love - Justin Bieber  0.078918    1
# 1                    One Less Lonely Girl - Justin Bieber  0.078641    2
# 2                                 Love Me - Justin Bieber  0.075318    3
# 3                       That Should Be Me - Justin Bieber  0.068665    4
# 4          Eenie Meenie - Sean Kingston and Justin Bieber  0.068524    5
# 5                        Never Let You Go - Justin Bieber  0.065359    6
# 6                                One Time - Justin Bieber  0.064433    7
# 7                           Down To Earth - Justin Bieber  0.063224    8
# 8                     First Dance - Justin Bieber / Usher  0.060046    9
# 9                                  Bigger - Justin Bieber  0.059701   10
